# %%
import numpy as np
import math
import matplotlib.pyplot as plt
#matplotlib inline
fig_size = np.array([18, 6])
plt.rcParams["figure.figsize"] = fig_size


# z = exp(s*T)
# s = (1/T)*ln(z)

# zoh
# z ~ 1 + s*T
# s ~ (z - 1)/T

# bilinear transform
# z ~ (2 + sT)/(2 - sT)
# s ~ (2/T)(z - 1)/(z + 1)

# %%
x = np.arange(-np.pi/2,np.pi/2,np.pi/1000)

plt.figure()
#plt.plot(x,x,'k--')
#plt.plot(x,np.sin(x))
plt.plot(x,np.sin(x)**2)
plt.plot(x,2*np.cos(x)*np.sin(x))
plt.plot(x,2*np.cos(x)*np.cos(x)-2*np.sin(x)*np.sin(x))
plt.plot([[np.pi/4, np.pi/4]],[[-2, 2]],'k')

plt.show()
